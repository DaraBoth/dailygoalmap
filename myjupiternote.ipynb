# %% [markdown]
# ## Project Error & Debug To-Do List
#
# - [ ] Push notifications to goal members may fail (see Copilot instructions)
# - [ ] Background sync may not trigger reliably (offlineSync, service worker)
# - [ ] Some TypeScript/type errors remain (review type usage in src/types/)
# - [ ] IndexedDB sync needs improvement (offlineSync, service worker)
# - [ ] Check error handling in Supabase API calls (clientApi.ts, supabaseOperations.ts)
# - [ ] Add automated tests for critical flows (no .test.tsx files found)
# - [ ] Review and optimize performance (React.memo, useMemo, useCallback)
# - [ ] Ensure proper error display in UI (GoalDetail.tsx, error state)
# - [ ] Centralize all Supabase API calls (avoid scattered logic)
# - [ ] Do NOT modify GoalList or TodayTasks components
